# %%
# %matplotlib inline
import networkx as nx
import shapefile
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.mpl_style = 'default'

# %%
# Natural Gas Processing Plants

ng_plants = pd.read_csv('data/Shapefile_NaturalGas_ProcessingPlants_US_EIA.csv')
ng_plants.head(2)
# Out:
#          Plant_Name State      County  PlantCapac  PlantFlow  BTU_Conten  \
# 0  Robin Hill Plant    PA  Washington          18          5        1328
# 1    Keystone Plant    PA      Butler         210        118        1221
#
#    DryGasStor  NG_LiquidS        City  ZipCode  \
# 0           0        1215      Bulger    15019
# 1           0           0  Evans City    16033
#
#                                OwnerCompa  \
# 0          Laurel Mountain Midstream, LLC
# 1  MarkWest Liberty Midstream & Resources
#
#                                OperatorCo  \
# 0          Laurel Mountain Midstream, LLC
# 1  MarkWest Liberty Midstream & Resources
#
#                                          Source        x        y
# 0  EIA-757, Natural Gas Processing Plant Survey -8941778  4924204
# 1  EIA-757, Natural Gas Processing Plant Survey -8910599  4981593

# %%
ng_plants.plot(kind='scatter', figsize=(14, 10), x='x', y='y')
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
ng_network = nx.read_shp('data/Shapefiles/Shapefile_HGL_Pipelines_US_EIA/HGL_Pipelines_US_Nov2014.shp')

# %%
nx.draw(ng_network, with_labels=False,arrows=False,node_size=1,width=1,edge_color='green')
